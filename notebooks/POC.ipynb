# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

# %%
from src.tools import research_tools

results = research_tools.tavily_search_tool("hiroshima pikachu")

# %%
results
# Out:
# [{'title': "Hiroshima's Pikachu (SV-P Promo 261) - Bulbapedia - Bulbagarden",
#   'content': "Hiroshima's Pikachu is a Lightning-type Basic Pokémon card. It is one of the SV-P Promotional cards.",
#   'url': 'https://bulbapedia.bulbagarden.net/wiki/Hiroshima%27s_Pikachu_(SV-P_Promo_261)'},
#  {'title': "Hiroshima's Pikachu #261/SV-P Pokemon Japanese Promo",
#   'content': "Full Price Guide: Hiroshima's Pikachu #261/SV-P (Pokemon Japanese Promo). Ungraded, $185.31. Grade 1, -. Grade 2, $7.00. Grade 3, $8.00. Grade 4",
#   'url': 'https://www.pricecharting.com/game/pokemon-japanese-promo/hiroshima%27s-pikachu-261sv-p'},
#  {'title': 'Pokemon Card Game Japanese Pokemon Center Hiroshima ...',
#   'content': 'Pokemon Card Game Japanese Pokemon Center Hiroshima Pikachu Special Box Set. No reviews. SKU: 4521329427669. $ 249.95. $ 249.95: $ 249.95. Unit price: / per.',
# ...
